# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("dataset_Facebook - dataset_Facebook.csv")
dataset
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
dataset.shape
# Out:
# (500, 19)

# %%
dataset.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
dataset = dataset.dropna()

# %%
dataset.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
sub1 = dataset[dataset['Page total likes']>= 100000]

# %%
sub1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 433            100732   Photo         1           3             6         17
# 434            100732   Photo         1           3             6         15
# 435            100732   Photo         1           3             6         15
# 436            100732   Photo         1           3             6         13
# 437            100732   Photo         1           3             6         10
#
# ...

# %%
sub2 = dataset[dataset['Type']=='Photo']

# %%
sub2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
#
# ...

# %%
sub3 = dataset[(dataset['Paid']==1) &( dataset['like'] > 150)]

# %%
sub3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 14             138414   Photo         2          12             4          5
# 17             138414   Photo         1          12             2         12
# 41             138895    Link         1          12             6          3
# 51             138329   Photo         1          11             1          3
# 62             138185   Photo         1          11             2         10
# 63             138185   Photo         1          11             2          3
# 67             138185   Photo         1          11             7          3
# 71             137893   Video         1          11             5          3
# ...

# %%
sub4 = dataset[(dataset['Paid']==1) &( dataset['Type'] == 'Video')]

# %%
sub4
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 29             138895  Video         1          12             4         11
# 55             138329  Video         1          11             6          2
# 71             137893  Video         1          11             5          3
# 243            130791  Video         1           7             3         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 29    1.0                      36208                            61262
# 55    1.0                      16416                            31950
# 71    1.0                     100768                           220447
# 243   1.0                      21872                            40413
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 29                     1141                     1068
# 55                      459                      411
# 71                     2101                     1735
# ...

# %%
sub5 = dataset[(dataset['comment']>50) &( dataset['share'] >50)]

# %%
sub5
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 142            136013  Status         2          10             3          2
# 168            135428   Photo         1           9             3         10
# 244            130791   Photo         2           7             3          5
# 379            111620   Photo         3           4             1         14
# 460             92507   Photo         3           2             1         13
# 480             86909   Photo         2           1             4         11
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 3     1.0                      50128                            87991
# 142   1.0                      31136                            59964
# 168   0.0                      41984                            68290
# 244   1.0                     180480                           319133
# ...

# %%
time = dataset.iloc[:,3:6]

# %%
time
# Out:
#      Post Month  Post Weekday  Post Hour
# 0            12             4          3
# 1            12             3         10
# 2            12             3          3
# 3            12             2         10
# 4            12             2          3
# ..          ...           ...        ...
# 494           1             7         10
# 495           1             7          2
# 496           1             5          8
# 497           1             5          2
# 498           1             4         11
#
# [495 rows x 3 columns]

# %%
dataset.iloc[:250,:]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 249            129600   Photo         2           7             7         11
# 250            129600   Photo         1           7             7          6
# 251            129600   Photo         1           7             6         11
# 252            129600   Photo         3           7             6          5
# 253            129600  Status         2           7             5         12
#
# ...

# %%
merge = pd.merge(sub3,sub4,on="Paid")

# %%
merge
# Out:
#      Page total likes_x Type_x  Category_x  Post Month_x  Post Weekday_x  \
# 0                139441  Photo           2            12               2
# 1                139441  Photo           2            12               2
# 2                139441  Photo           2            12               2
# 3                139441  Photo           2            12               2
# 4                139441  Photo           3            12               1
# ..                  ...    ...         ...           ...             ...
# 215               91758  Photo           2             2               5
# 216               86909  Photo           1             1               6
# 217               86909  Photo           1             1               6
# 218               86909  Photo           1             1               6
# 219               86909  Photo           1             1               6
#
#      Post Hour_x  Paid  Lifetime Post Total Reach_x  \
# ...

# %%
dataset.sort_values("Page total likes",ascending = True)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 496             81370   Photo         2           1             5          8
# 493             85093   Photo         3           1             1          2
# 495             85093   Photo         3           1             7          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
subset = dataset

# %%
pivot = pd.pivot_table(dataset,index='Post Month',columns = 'Category',values = 'like',aggfunc = "sum")

# %%
pivot
# Out:
# Category         1       2       3
# Post Month
# 1            918.0   482.0  1581.0
# 2           1547.0   376.0  3094.0
# 3           2118.0    80.0   794.0
# 4           2708.0  1656.0  4773.0
# 5            773.0  1263.0  5962.0
# 6           1969.0  1198.0  3380.0
# 7           2602.0  8432.0  3137.0
# 8           1755.0  1469.0  3523.0
# 9           2651.0  2725.0  2920.0
# 10          2936.0  4701.0  1593.0
# 11          5082.0   392.0  1478.0
# 12          1640.0  5567.0  1402.0

# %%
pivot_T = pivot.T

# %%
pivot_T
# Out:
# Post Month      1       2       3       4       5       6       7       8   \
# Category
# 1            918.0  1547.0  2118.0  2708.0   773.0  1969.0  2602.0  1755.0
# 2            482.0   376.0    80.0  1656.0  1263.0  1198.0  8432.0  1469.0
# 3           1581.0  3094.0   794.0  4773.0  5962.0  3380.0  3137.0  3523.0
#
# Post Month      9       10      11      12
# Category
# 1           2651.0  2936.0  5082.0  1640.0
# 2           2725.0  4701.0   392.0  5567.0
# 3           2920.0  1593.0  1478.0  1402.0

# %%
data = dataset.T
data
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
plt.barh(dataset['Post Month'],dataset['like'])
plt.ylabel("Months")
plt.xlabel("likes")
# Out:
# Text(0.5, 0, 'likes')

# %%
plt.pie(dataset['Paid'].value_counts())
label = ["paid","not paid"]
plt.legend(label)

# %%
plt.bar(dataset['Type'],dataset['share'])
plt.xlabel("TYPE")
plt.ylabel("Share")
# Out:
# Text(0, 0.5, 'Share')

# %%
sns.countplot(dataset['Type'])
# Out:
# <Axes: xlabel='count', ylabel='Type'>

# %%
data_melt = pd.melt(dataset,id_vars = 'Category',value_vars = ['like','share'])

# %%
data_melt
# Out:
#      Category variable   value
# 0           2     like    79.0
# 1           2     like   130.0
# 2           3     like    66.0
# 3           2     like  1572.0
# 4           2     like   325.0
# ..        ...      ...     ...
# 985         3    share    41.0
# 986         3    share    26.0
# 987         2    share    22.0
# 988         1    share    18.0
# 989         3    share    38.0
#
# [990 rows x 3 columns]
